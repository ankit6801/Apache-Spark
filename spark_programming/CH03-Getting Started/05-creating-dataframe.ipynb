# %% [markdown]
# 1. Create a Dataframe using a connector

# %%
file_df = (
    spark.read.format("csv")
    .option("header","true")
    .option("inferschema","true")
    .load("/Volumes/dev_catalog/spark_db/datasets/spark_programming/data/sf-fire-calls.csv")
)

# %%
json_file_df = (
    spark.read.format("json")
    .load("/Volumes/dev_catalog/spark_db/datasets/spark_programming/data/diamonds.json")
)

# %% [markdown]
# 2. Create a Dataframe reading a Spark table

# %%
table_df = spark.table("dev_catalog.spark_db.diamonds")

# %% [markdown]
# 3. Create a Dataframe reading the result of a SQL query

# %%
table_name  = "dev_catalog.spark_db.sf_fire_calls"
sql_query_df = spark.sql(f"select * from {table_name} limit 7"
)

sql_query_df.display()

# %% [markdown]
# 4. Create dataframe from Python List

# %%
from datetime import datetime,date
data_list_schema = "id long, name string, joining_date date, salary double, created_at timestamp"
data_list =[(1, "Ankit",date(2018,1,1),930.0,datetime(2022,1,9,0)),
            (2, "Ram", date(2001, 2, 1), 1260.50, datetime(2022, 1, 2, 11, 0)),
            (3, "Bittu", date(2022, 3, 1), 765.0, datetime(2022, 1, 3, 10, 0))
            ]
list_df = spark.createDataFrame(data_list,data_list_schema)

# %% [markdown]
# 5. Create a single column dataframe from a range

# %%
range_df = spark.range(1000,1010,2).display()
