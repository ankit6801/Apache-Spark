# %% [markdown]
# # 1. Run  Unit Test

# %% [markdown]
# 1.1 Reload during development

# %%
# %load_ext autoreload
# %load autoreload 2

# %% [markdown]
# 1.2 Run Unit Test

# %%
import pytest
import sys


# What is the purpose of the this line (bytecode) because pytest take our code generate bytecode for faster execution so to avoide doing this we write this line.
sys.dont_write_bytecode = True

returncode = pytest.main(['.','-v','-p','no:cacheprovider'])

# assert eyword use like conditional statement to check/match value.
assert returncode == 0, "The pytest ivocation failed."
