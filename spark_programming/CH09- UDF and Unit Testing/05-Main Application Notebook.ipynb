# %% [markdown]
# # 1. Main Application notebook

# %% [markdown]
# 1.1 Reload during Development

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# 1.2 Main Application Code

# %%
from booking_analysis import read_booking_summary, top_3_revenue, PrintName

pathh = 'dbfs:/Volumes/dev_catalog/spark_db/datasets/spark_programming/data/booking-summary.csv'
summary_df = read_booking_summary(spark)
result_df =  top_3_revenue(summary_df)

result_df.display()

# %%
PrintName()
